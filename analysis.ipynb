# %%
import pandas as pd

# %%
data = pd.read_csv('data/AppGallery.csv')
data.head()
for col in ['Unnamed: 11', 'Unnamed: 12']:
    print(col , "=" * 50)
    print(data[col].value_counts())
print(data.columns)
# Out:
# Unnamed: 11 ==================================================
# Unnamed: 11
# Can't install Apps    1
# Name: count, dtype: int64
# Unnamed: 12 ==================================================
# Series([], Name: count, dtype: int64)
# Index(['Ticket id', 'Interaction id', 'Interaction date', 'Mailbox',
#        'Ticket Summary', 'Interaction content', 'Innso TYPOLOGY_TICKET ',
#        'Type 1', 'Type 2', 'Type 3', 'Type 4', 'Unnamed: 11', 'Unnamed: 12'],
#       dtype='str')

# %%
data = pd.read_csv('data/Purchasing.csv')
data.head()
for col in ["Type 1", "Type 2", "Type 3", "Type 4"]:
    print(col , "=" * 50)
    print(data[col].value_counts())
print(data.columns)
# Out:
# Type 1 ==================================================
# Type 1
# In-App Purchase     84
# Name: count, dtype: int64
# Type 2 ==================================================
# Type 2
# Suggestion       72
# Problem/Fault    10
# Others            2
# Name: count, dtype: int64
# Type 3 ==================================================
# Type 3
# Payment          57
# Payment issue    10
# Invoice           8
# Other             6
# Refund            1
# Name: count, dtype: int64
# Type 4 ==================================================
# Type 4
# Subscription cancellation                         52
# Invoice related request                            8
# Risk Control                                       8
# Query deduction details                            5
# Payment failed                                     2
# Within 14 days of purchase (not product issue)     1
# Name: count, dtype: int64
# Index(['Ticket id', 'Interaction id', 'Interaction date', 'Mailbox',
# ...
